# %% [markdown]
# # SHL Assessment Recommendation System

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer,util
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
catalog_df = pd.read_csv("SHL_sample_data.csv") # sample dataset
catalog_df
# Out:
#                             Assessment Name                            URL  \
# 0              Java Developer Assessment #1   https://shl.com/assessment/1
# 1              Full Stack Developer Test #2   https://shl.com/assessment/2
# 2                 Data Analyst Screening #3   https://shl.com/assessment/3
# 3                 Python & SQL Challenge #4   https://shl.com/assessment/4
# 4                Cognitive Aptitude Test #5   https://shl.com/assessment/5
# 5        Personality Insights Assessment #6   https://shl.com/assessment/6
# 6         Frontend Developer Skills Test #7   https://shl.com/assessment/7
# 7      Business Communication Evaluation #8   https://shl.com/assessment/8
# 8           Logical Reasoning Assessment #9   https://shl.com/assessment/9
# 9       Coding Challenge for Developers #10  https://shl.com/assessment/10
# 10            JavaScript Screening Test #11  https://shl.com/assessment/11
# 11   Problem Solving & Coding Challenge #12  https://shl.com/assessment/12
# 12              Technical Aptitude Test #13  https://shl.com/assessment/13
# 13  Developer Collaboration Skills Test #14  https://shl.com/assessment/14
# 14             Personality Fit Analysis #15  https://shl.com/assessment/15
# 15            Business Analyst Aptitude #16  https://shl.com/assessment/16
# 16  Python Backend Developer Assessment #17  https://shl.com/assessment/17
# 17            SQL & Reporting Challenge #18  https://shl.com/assessment/18
# 18            Communication Skills Test #19  https://shl.com/assessment/19
# 19       Mid-Level Developer Evaluation #20  https://shl.com/assessment/20
# 20          Senior Engineer Coding Test #21  https://shl.com/assessment/21
# 21               Quick Logic Assessment #22  https://shl.com/assessment/22
# 22      Entry-Level Developer Screening #23  https://shl.com/assessment/23
# 23             Communication & Team Fit #24  https://shl.com/assessment/24
# 24     Developer Personality Assessment #25  https://shl.com/assessment/25
# 25                     SQL Mastery Test #26  https://shl.com/assessment/26
# 26                 Quick Java Screening #27  https://shl.com/assessment/27
# 27      Collaboration Skills Evaluation #28  https://shl.com/assessment/28
# 28          Backend Developer Challenge #29  https://shl.com/assessment/29
# 29    Critical Thinking & Aptitude Test #30  https://shl.com/assessment/30
# 30      Personality & Communication Fit #31  https://shl.com/assessment/31
# 31            JavaScript Developer Test #32  https://shl.com/assessment/32
# 32             Data Interpretation Test #33  https://shl.com/assessment/33
# 33            Junior Developer Aptitude #34  https://shl.com/assessment/34
# 34         Communication & Presentation #35  https://shl.com/assessment/35
# 35                Cognitive Quick Check #36  https://shl.com/assessment/36
# 36            Code Debugging Assessment #37  https://shl.com/assessment/37
# 37                   SQL Reporting Task #38  https://shl.com/assessment/38
# 38           Advanced Coding Simulation #39  https://shl.com/assessment/39
# 39                 Personality Profiler #40  https://shl.com/assessment/40
# 40          Cross-functional Assessment #41  https://shl.com/assessment/41
# 41             Entry-level Analyst Test #42  https://shl.com/assessment/42
# 42      Interpersonal Skills Assessment #43  https://shl.com/assessment/43
# 43         Python Code Review Challenge #44  https://shl.com/assessment/44
# 44         Logical Decision Making Test #45  https://shl.com/assessment/45
# 45    Advanced Personality & Leadership #46  https://shl.com/assessment/46
# 46                    Java Coding Drill #47  https://shl.com/assessment/47
# 47              Behavioral Traits Check #48  https://shl.com/assessment/48
# 48          Cognitive & Technical Combo #49  https://shl.com/assessment/49
# 49         Comprehensive Developer Test #50  https://shl.com/assessment/50
#
#     Duration Remote Testing Support Adaptive/IRT      Test Type  \
# 0         40                    Yes           No         Coding
# 1         50                    Yes          Yes         Coding
# 2         45                     No           No      Cognitive
# 3         60                    Yes          Yes         Coding
# 4         30                    Yes           No      Cognitive
# 5         35                    Yes           No    Personality
# 6         45                     No          Yes         Coding
# 7         25                    Yes          Yes  Communication
# 8         20                    Yes           No      Cognitive
# 9         60                     No          Yes         Coding
# 10        30                    Yes          Yes         Coding
# 11        55                     No           No         Coding
# 12        35                    Yes           No       Aptitude
# 13        40                    Yes          Yes  Communication
# 14        30                    Yes           No    Personality
# 15        45                     No          Yes      Cognitive
# 16        60                    Yes          Yes         Coding
# 17        40                    Yes           No         Coding
# 18        30                    Yes          Yes  Communication
# 19        55                    Yes          Yes         Coding
# 20        60                    Yes          Yes         Coding
# 21        20                    Yes           No      Cognitive
# 22        30                    Yes           No         Coding
# 23        25                    Yes          Yes  Communication
# 24        30                     No           No    Personality
# 25        40                    Yes          Yes         Coding
# 26        30                    Yes           No         Coding
# 27        35                     No          Yes  Communication
# 28        60                    Yes          Yes         Coding
# 29        40                    Yes           No      Cognitive
# 30        30                    Yes           No    Personality
# 31        50                     No          Yes         Coding
# 32        45                    Yes          Yes      Cognitive
# 33        35                    Yes           No         Coding
# 34        30                    Yes          Yes  Communication
# 35        20                    Yes           No      Cognitive
# 36        45                     No          Yes         Coding
# 37        30                    Yes           No         Coding
# 38        60                    Yes          Yes         Coding
# 39        30                    Yes          Yes    Personality
# 40        50                    Yes           No      Cognitive
# 41        30                    Yes           No      Cognitive
# 42        30                    Yes           No  Communication
# 43        60                    Yes          Yes         Coding
# 44        25                    Yes           No      Cognitive
# 45        45                    Yes          Yes    Personality
# 46        40                    Yes           No         Coding
# 47        30                    Yes           No    Personality
# 48        55                    Yes          Yes      Cognitive
# 49        60                    Yes          Yes         Coding
#
#              Skills                                        Description
# 0              Java  The 'Java Developer Assessment #1' is a Coding...
# 1        JavaScript                                             Python
# 2               SQL                                             Python
# 3            Python                                                SQL
# 4   Problem Solving  The 'Cognitive Aptitude Test #5' is a Cognitiv...
# 5          Teamwork                                      Communication
# 6        JavaScript                                      Communication
# 7     Communication                                           Teamwork
# 8   Problem Solving  The 'Logical Reasoning Assessment #9' is a Cog...
# 9            Python                                               Java
# 10       JavaScript  The 'JavaScript Screening Test #11' is a Codin...
# 11             Java                                    Problem Solving
# 12            Logic                                    Problem Solving
# 13         Teamwork                                      Communication
# 14      Personality                                           Teamwork
# 15              SQL                                    Problem Solving
# 16           Python                                    Problem Solving
# 17              SQL                                             Python
# 18    Communication  The 'Communication Skills Test #19' is a Commu...
# 19           Python                                         JavaScript
# 20             Java                                             Python
# 21  Problem Solving  The 'Quick Logic Assessment #22' is a Cognitiv...
# 22           Python                                         JavaScript
# 23         Teamwork                                      Communication
# 24      Personality  The 'Developer Personality Assessment #25' is ...
# 25              SQL  The 'SQL Mastery Test #26' is a Coding test fo...
# 26             Java  The 'Quick Java Screening #27' is a Coding tes...
# 27         Teamwork  The 'Collaboration Skills Evaluation #28' is a...
# 28           Python                                                SQL
# 29  Problem Solving  The 'Critical Thinking & Aptitude Test #30' is...
# 30    Communication  The 'Personality & Communication Fit #31' is a...
# 31       JavaScript  The 'JavaScript Developer Test #32' is a Codin...
# 32    Data Analysis                                                SQL
# 33           Python                                         JavaScript
# 34    Communication                                       Presentation
# 35            Logic  The 'Cognitive Quick Check #36' is a Cognitive...
# 36       JavaScript                                             Python
# 37              SQL  The 'SQL Reporting Task #38' is a Coding test ...
# 38             Java                                             Python
# 39      Personality  The 'Personality Profiler #40' is a Personalit...
# 40              SQL                                             Python
# 41  Problem Solving                                                SQL
# 42         Teamwork                                      Communication
# 43           Python  The 'Python Code Review Challenge #44' is a Co...
# 44            Logic  The 'Logical Decision Making Test #45' is a Co...
# 45       Leadership                                        Personality
# 46             Java  The 'Java Coding Drill #47' is a Coding test f...
# 47         Behavior  The 'Behavioral Traits Check #48' is a Persona...
# 48       JavaScript                                              Logic
# 49           Python                                         JavaScript

# %%
catalog_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Assessment Name         50 non-null     object
#  1   URL                     50 non-null     object
#  2   Duration                50 non-null     int64
#  3   Remote Testing Support  50 non-null     object
#  4   Adaptive/IRT            50 non-null     object
#  5   Test Type               50 non-null     object
#  6   Skills                  50 non-null     object
#  7   Description             50 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 3.3+ KB

# %%
def combine_row(row):
    parts = [
        str(row["Assessment Name"]),
        str(row["Duration"]),
        str(row["Remote Testing Support"]),
        str(row["Adaptive/IRT"]),
        str(row["Test Type"]),
        str(row["Skills"]),
        str(row["Description"]),
    ]
    return ' '.join(parts)

# %%
catalog_df['combined'] = catalog_df.apply(combine_row,axis=1)

# %%
catalog_df
# Out:
#                             Assessment Name                            URL  \
# 0              Java Developer Assessment #1   https://shl.com/assessment/1
# 1              Full Stack Developer Test #2   https://shl.com/assessment/2
# 2                 Data Analyst Screening #3   https://shl.com/assessment/3
# 3                 Python & SQL Challenge #4   https://shl.com/assessment/4
# 4                Cognitive Aptitude Test #5   https://shl.com/assessment/5
# 5        Personality Insights Assessment #6   https://shl.com/assessment/6
# 6         Frontend Developer Skills Test #7   https://shl.com/assessment/7
# 7      Business Communication Evaluation #8   https://shl.com/assessment/8
# 8           Logical Reasoning Assessment #9   https://shl.com/assessment/9
# 9       Coding Challenge for Developers #10  https://shl.com/assessment/10
# 10            JavaScript Screening Test #11  https://shl.com/assessment/11
# 11   Problem Solving & Coding Challenge #12  https://shl.com/assessment/12
# 12              Technical Aptitude Test #13  https://shl.com/assessment/13
# 13  Developer Collaboration Skills Test #14  https://shl.com/assessment/14
# 14             Personality Fit Analysis #15  https://shl.com/assessment/15
# 15            Business Analyst Aptitude #16  https://shl.com/assessment/16
# 16  Python Backend Developer Assessment #17  https://shl.com/assessment/17
# 17            SQL & Reporting Challenge #18  https://shl.com/assessment/18
# 18            Communication Skills Test #19  https://shl.com/assessment/19
# 19       Mid-Level Developer Evaluation #20  https://shl.com/assessment/20
# 20          Senior Engineer Coding Test #21  https://shl.com/assessment/21
# 21               Quick Logic Assessment #22  https://shl.com/assessment/22
# 22      Entry-Level Developer Screening #23  https://shl.com/assessment/23
# 23             Communication & Team Fit #24  https://shl.com/assessment/24
# 24     Developer Personality Assessment #25  https://shl.com/assessment/25
# 25                     SQL Mastery Test #26  https://shl.com/assessment/26
# 26                 Quick Java Screening #27  https://shl.com/assessment/27
# 27      Collaboration Skills Evaluation #28  https://shl.com/assessment/28
# 28          Backend Developer Challenge #29  https://shl.com/assessment/29
# 29    Critical Thinking & Aptitude Test #30  https://shl.com/assessment/30
# 30      Personality & Communication Fit #31  https://shl.com/assessment/31
# 31            JavaScript Developer Test #32  https://shl.com/assessment/32
# 32             Data Interpretation Test #33  https://shl.com/assessment/33
# 33            Junior Developer Aptitude #34  https://shl.com/assessment/34
# 34         Communication & Presentation #35  https://shl.com/assessment/35
# 35                Cognitive Quick Check #36  https://shl.com/assessment/36
# 36            Code Debugging Assessment #37  https://shl.com/assessment/37
# 37                   SQL Reporting Task #38  https://shl.com/assessment/38
# 38           Advanced Coding Simulation #39  https://shl.com/assessment/39
# 39                 Personality Profiler #40  https://shl.com/assessment/40
# 40          Cross-functional Assessment #41  https://shl.com/assessment/41
# 41             Entry-level Analyst Test #42  https://shl.com/assessment/42
# 42      Interpersonal Skills Assessment #43  https://shl.com/assessment/43
# 43         Python Code Review Challenge #44  https://shl.com/assessment/44
# 44         Logical Decision Making Test #45  https://shl.com/assessment/45
# 45    Advanced Personality & Leadership #46  https://shl.com/assessment/46
# 46                    Java Coding Drill #47  https://shl.com/assessment/47
# 47              Behavioral Traits Check #48  https://shl.com/assessment/48
# 48          Cognitive & Technical Combo #49  https://shl.com/assessment/49
# 49         Comprehensive Developer Test #50  https://shl.com/assessment/50
#
#     Duration Remote Testing Support Adaptive/IRT      Test Type  \
# 0         40                    Yes           No         Coding
# 1         50                    Yes          Yes         Coding
# 2         45                     No           No      Cognitive
# 3         60                    Yes          Yes         Coding
# 4         30                    Yes           No      Cognitive
# 5         35                    Yes           No    Personality
# 6         45                     No          Yes         Coding
# 7         25                    Yes          Yes  Communication
# 8         20                    Yes           No      Cognitive
# 9         60                     No          Yes         Coding
# 10        30                    Yes          Yes         Coding
# 11        55                     No           No         Coding
# 12        35                    Yes           No       Aptitude
# 13        40                    Yes          Yes  Communication
# 14        30                    Yes           No    Personality
# 15        45                     No          Yes      Cognitive
# 16        60                    Yes          Yes         Coding
# 17        40                    Yes           No         Coding
# 18        30                    Yes          Yes  Communication
# 19        55                    Yes          Yes         Coding
# 20        60                    Yes          Yes         Coding
# 21        20                    Yes           No      Cognitive
# 22        30                    Yes           No         Coding
# 23        25                    Yes          Yes  Communication
# 24        30                     No           No    Personality
# 25        40                    Yes          Yes         Coding
# 26        30                    Yes           No         Coding
# 27        35                     No          Yes  Communication
# 28        60                    Yes          Yes         Coding
# 29        40                    Yes           No      Cognitive
# 30        30                    Yes           No    Personality
# 31        50                     No          Yes         Coding
# 32        45                    Yes          Yes      Cognitive
# 33        35                    Yes           No         Coding
# 34        30                    Yes          Yes  Communication
# 35        20                    Yes           No      Cognitive
# 36        45                     No          Yes         Coding
# 37        30                    Yes           No         Coding
# 38        60                    Yes          Yes         Coding
# 39        30                    Yes          Yes    Personality
# 40        50                    Yes           No      Cognitive
# 41        30                    Yes           No      Cognitive
# 42        30                    Yes           No  Communication
# 43        60                    Yes          Yes         Coding
# 44        25                    Yes           No      Cognitive
# 45        45                    Yes          Yes    Personality
# 46        40                    Yes           No         Coding
# 47        30                    Yes           No    Personality
# 48        55                    Yes          Yes      Cognitive
# 49        60                    Yes          Yes         Coding
#
#              Skills                                        Description  \
# 0              Java  The 'Java Developer Assessment #1' is a Coding...
# 1        JavaScript                                             Python
# 2               SQL                                             Python
# 3            Python                                                SQL
# 4   Problem Solving  The 'Cognitive Aptitude Test #5' is a Cognitiv...
# 5          Teamwork                                      Communication
# 6        JavaScript                                      Communication
# 7     Communication                                           Teamwork
# 8   Problem Solving  The 'Logical Reasoning Assessment #9' is a Cog...
# 9            Python                                               Java
# 10       JavaScript  The 'JavaScript Screening Test #11' is a Codin...
# 11             Java                                    Problem Solving
# 12            Logic                                    Problem Solving
# 13         Teamwork                                      Communication
# 14      Personality                                           Teamwork
# 15              SQL                                    Problem Solving
# 16           Python                                    Problem Solving
# 17              SQL                                             Python
# 18    Communication  The 'Communication Skills Test #19' is a Commu...
# 19           Python                                         JavaScript
# 20             Java                                             Python
# 21  Problem Solving  The 'Quick Logic Assessment #22' is a Cognitiv...
# 22           Python                                         JavaScript
# 23         Teamwork                                      Communication
# 24      Personality  The 'Developer Personality Assessment #25' is ...
# 25              SQL  The 'SQL Mastery Test #26' is a Coding test fo...
# 26             Java  The 'Quick Java Screening #27' is a Coding tes...
# 27         Teamwork  The 'Collaboration Skills Evaluation #28' is a...
# 28           Python                                                SQL
# 29  Problem Solving  The 'Critical Thinking & Aptitude Test #30' is...
# 30    Communication  The 'Personality & Communication Fit #31' is a...
# 31       JavaScript  The 'JavaScript Developer Test #32' is a Codin...
# 32    Data Analysis                                                SQL
# 33           Python                                         JavaScript
# 34    Communication                                       Presentation
# 35            Logic  The 'Cognitive Quick Check #36' is a Cognitive...
# 36       JavaScript                                             Python
# 37              SQL  The 'SQL Reporting Task #38' is a Coding test ...
# 38             Java                                             Python
# 39      Personality  The 'Personality Profiler #40' is a Personalit...
# 40              SQL                                             Python
# 41  Problem Solving                                                SQL
# 42         Teamwork                                      Communication
# 43           Python  The 'Python Code Review Challenge #44' is a Co...
# 44            Logic  The 'Logical Decision Making Test #45' is a Co...
# 45       Leadership                                        Personality
# 46             Java  The 'Java Coding Drill #47' is a Coding test f...
# 47         Behavior  The 'Behavioral Traits Check #48' is a Persona...
# 48       JavaScript                                              Logic
# 49           Python                                         JavaScript
#
#                                              combined
# 0   Java Developer Assessment #1 40 Yes No Coding ...
# 1   Full Stack Developer Test #2 50 Yes Yes Coding...
# 2   Data Analyst Screening #3 45 No No Cognitive S...
# 3   Python & SQL Challenge #4 60 Yes Yes Coding Py...
# 4   Cognitive Aptitude Test #5 30 Yes No Cognitive...
# 5   Personality Insights Assessment #6 35 Yes No P...
# 6   Frontend Developer Skills Test #7 45 No Yes Co...
# 7   Business Communication Evaluation #8 25 Yes Ye...
# 8   Logical Reasoning Assessment #9 20 Yes No Cogn...
# 9   Coding Challenge for Developers #10 60 No Yes ...
# 10  JavaScript Screening Test #11 30 Yes Yes Codin...
# 11  Problem Solving & Coding Challenge #12 55 No N...
# 12  Technical Aptitude Test #13 35 Yes No Aptitude...
# 13  Developer Collaboration Skills Test #14 40 Yes...
# 14  Personality Fit Analysis #15 30 Yes No Persona...
# 15  Business Analyst Aptitude #16 45 No Yes Cognit...
# 16  Python Backend Developer Assessment #17 60 Yes...
# 17  SQL & Reporting Challenge #18 40 Yes No Coding...
# 18  Communication Skills Test #19 30 Yes Yes Commu...
# 19  Mid-Level Developer Evaluation #20 55 Yes Yes ...
# 20  Senior Engineer Coding Test #21 60 Yes Yes Cod...
# 21  Quick Logic Assessment #22 20 Yes No Cognitive...
# 22  Entry-Level Developer Screening #23 30 Yes No ...
# 23  Communication & Team Fit #24 25 Yes Yes Commun...
# 24  Developer Personality Assessment #25 30 No No ...
# 25  SQL Mastery Test #26 40 Yes Yes Coding SQL The...
# 26  Quick Java Screening #27 30 Yes No Coding Java...
# 27  Collaboration Skills Evaluation #28 35 No Yes ...
# 28  Backend Developer Challenge #29 60 Yes Yes Cod...
# 29  Critical Thinking & Aptitude Test #30 40 Yes N...
# 30  Personality & Communication Fit #31 30 Yes No ...
# 31  JavaScript Developer Test #32 50 No Yes Coding...
# 32  Data Interpretation Test #33 45 Yes Yes Cognit...
# 33  Junior Developer Aptitude #34 35 Yes No Coding...
# 34  Communication & Presentation #35 30 Yes Yes Co...
# 35  Cognitive Quick Check #36 20 Yes No Cognitive ...
# 36  Code Debugging Assessment #37 45 No Yes Coding...
# 37  SQL Reporting Task #38 30 Yes No Coding SQL Th...
# 38  Advanced Coding Simulation #39 60 Yes Yes Codi...
# 39  Personality Profiler #40 30 Yes Yes Personalit...
# 40  Cross-functional Assessment #41 50 Yes No Cogn...
# 41  Entry-level Analyst Test #42 30 Yes No Cogniti...
# 42  Interpersonal Skills Assessment #43 30 Yes No ...
# 43  Python Code Review Challenge #44 60 Yes Yes Co...
# 44  Logical Decision Making Test #45 25 Yes No Cog...
# 45  Advanced Personality & Leadership #46 45 Yes Y...
# 46  Java Coding Drill #47 40 Yes No Coding Java Th...
# 47  Behavioral Traits Check #48 30 Yes No Personal...
# 48  Cognitive & Technical Combo #49 55 Yes Yes Cog...
# 49  Comprehensive Developer Test #50 60 Yes Yes Co...

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
#converting each row into a vector/word embedding
corpus = catalog_df['combined'].tolist()
corpus_embeddings = model.encode(corpus,convert_to_tensor=True)

# %%
corpus_embeddings
# Out:
# tensor([[-4.1132e-02,  3.3712e-02, -1.5192e-02,  ...,  6.8478e-02,
#           1.1157e-02, -3.8792e-02],
#         [-8.3015e-02, -5.8202e-02,  3.8498e-02,  ...,  1.4818e-01,
#           8.3665e-02, -4.9551e-02],
#         [ 2.8609e-02,  1.4035e-02, -4.8932e-02,  ...,  6.8456e-03,
#           6.1058e-02, -2.2603e-05],
#         ...,
#         [ 5.7849e-02,  1.8829e-02, -1.3150e-02,  ...,  4.9492e-02,
#          -7.7539e-03, -8.2473e-02],
#         [ 3.9873e-02,  2.4800e-03, -2.5676e-02,  ...,  3.8942e-02,
#           8.5604e-03, -4.1729e-02],
#         [-1.0276e-01, -2.3152e-02,  1.3055e-02,  ...,  1.6705e-01,
#           8.0500e-02, -2.7817e-02]], device='mps:0')

# %%
def print_assessments(user_query):
    model = SentenceTransformer('all-MiniLM-L6-v2')
    query_embedding = model.encode(user_query, convert_to_tensor = True)
    cosine_scores = util.cos_sim(query_embedding,corpus_embeddings)[0]
    top_k = min(5,len(corpus))
    top_results = torch.topk(cosine_scores,k=top_k)
    print('Top 5 Matching Assessments:\n')
    results = []
    for score, idx in zip(top_results[0], top_results[1]):
        idx = idx.item()
        result = {
            "Assessment Name": catalog_df.iloc[idx]['Assessment Name'],
            "Skills": catalog_df.iloc[idx]['Skills'],
            "Test Type": catalog_df.iloc[idx]['Test Type'],
            "Description": catalog_df.iloc[idx]['Description'],
            "Remote Testing Support": catalog_df.iloc[idx]['Remote Testing Support'],
            "Adaptive/IRT": catalog_df.iloc[idx]['Adaptive/IRT'],
            "Duration": catalog_df.iloc[idx]['Duration'],
            "URL": catalog_df.iloc[idx]['URL'],
            "Score": round(score.item(), 4)
        }

        print(f"Assessment: {result['Assessment Name']}")
        print(f"Skills: {result['Skills']}")
        print(f"Test Type: {result['Test Type']}")
        print(f"Description: {result['Description']}")
        print(f"Remote Testing Support: {result['Remote Testing Support']}")
        print(f"Adaptive/IRT: {result['Adaptive/IRT']}")
        print(f"Duration: {result['Duration']} mins")
        print(f"URL: {result['URL']}")
        print(f"Score: {result['Score']}")
        print("-" * 50)
        
        results.append(result)
    return results

# %%
user_query = input("Enter your query:")
print("\n")
results = print_assessments(user_query)
# Out:
# Enter your query: python sql coding test
# Top 5 Matching Assessments:
#
# Assessment: Python & SQL Challenge #4
# Skills: Python
# Test Type: Coding
# Description: SQL
# Remote Testing Support: Yes
# Adaptive/IRT: Yes
# Duration: 60 mins
# URL: https://shl.com/assessment/4
# Score: 0.7926
# --------------------------------------------------
# Assessment: Backend Developer Challenge #29
# Skills: Python
# Test Type: Coding
# Description: SQL
# Remote Testing Support: Yes
# Adaptive/IRT: Yes
# Duration: 60 mins
# URL: https://shl.com/assessment/29
# Score: 0.7855
# --------------------------------------------------
# Assessment: SQL & Reporting Challenge #18
# Skills: SQL
# Test Type: Coding
# Description: Python
# Remote Testing Support: Yes
# Adaptive/IRT: No
# Duration: 40 mins
# URL: https://shl.com/assessment/18
# Score: 0.7318
# --------------------------------------------------
# Assessment: Data Analyst Screening #3
# Skills: SQL
# Test Type: Cognitive
# Description: Python
# Remote Testing Support: No
# Adaptive/IRT: No
# Duration: 45 mins
# URL: https://shl.com/assessment/3
# Score: 0.6229
# --------------------------------------------------
# Assessment: Senior Engineer Coding Test #21
# Skills: Java
# Test Type: Coding
# Description: Python
# Remote Testing Support: Yes
# Adaptive/IRT: Yes
# Duration: 60 mins
# URL: https://shl.com/assessment/21
# Score: 0.5854
# --------------------------------------------------

# %%
user_query2 = input("Enter your query:")
print("\n")
result2 = print_assessments(user_query2)
# Out:
# Enter your query: I am hiring for an analyst and wants applications to screen using Cognitive and personality tests, what options are available within 45 mins.
# Top 5 Matching Assessments:
#
# Assessment: Cognitive Aptitude Test #5
# Skills: Problem Solving
# Test Type: Cognitive
# Description: The 'Cognitive Aptitude Test #5' is a Cognitive test focused on Problem Solving. Duration is 30 mins. It supports remote testing: Yes and adaptive format: No.
# Remote Testing Support: Yes
# Adaptive/IRT: No
# Duration: 30 mins
# URL: https://shl.com/assessment/5
# Score: 0.5845
# --------------------------------------------------
# Assessment: Critical Thinking & Aptitude Test #30
# Skills: Problem Solving
# Test Type: Cognitive
# Description: The 'Critical Thinking & Aptitude Test #30' is a Cognitive test focused on Problem Solving. Duration is 40 mins. It supports remote testing: Yes and adaptive format: No.
# Remote Testing Support: Yes
# Adaptive/IRT: No
# Duration: 40 mins
# URL: https://shl.com/assessment/30
# Score: 0.5815
# --------------------------------------------------
# Assessment: Developer Personality Assessment #25
# Skills: Personality
# Test Type: Personality
# Description: The 'Developer Personality Assessment #25' is a Personality test focused on Personality. Duration is 30 mins. It supports remote testing: No and adaptive format: No.
# Remote Testing Support: No
# Adaptive/IRT: No
# Duration: 30 mins
# URL: https://shl.com/assessment/25
# Score: 0.5472
# --------------------------------------------------
# Assessment: Quick Logic Assessment #22
# Skills: Problem Solving
# Test Type: Cognitive
# Description: The 'Quick Logic Assessment #22' is a Cognitive test focused on Problem Solving. Duration is 20 mins. It supports remote testing: Yes and adaptive format: No.
# Remote Testing Support: Yes
# Adaptive/IRT: No
# Duration: 20 mins
# URL: https://shl.com/assessment/22
# Score: 0.5407
# --------------------------------------------------
# Assessment: Behavioral Traits Check #48
# Skills: Behavior
# Test Type: Personality
# Description: The 'Behavioral Traits Check #48' is a Personality test focused on Behavior. Duration is 30 mins. It supports remote testing: Yes and adaptive format: No.
# Remote Testing Support: Yes
# Adaptive/IRT: No
# Duration: 30 mins
# URL: https://shl.com/assessment/48
# Score: 0.5407
# --------------------------------------------------

# %%
def compute_metrics(benchmark_queries,k=5):
    recall_scores = []
    average_precisions = []

    for entry in benchmark_queries:
        query = entry["query"]
        relevant_items = entry["relevant"]

        results = find_assessments(query)
        topk = [res["Assessment Name"] for res in results[:k]]

        #recall@k
        count = 0
        for item in topk:
            if item in relevant_items:
                count+=1
        recall_score = count/len(relevant_items)
        recall_scores.append(recall_score)

        #map@k
        ap = 0.0
        relevant_count = 0
        for i,res in enumerate(topk):
            if res in relevant_items:
                relevant_count+=1
                precision_at_k = relevant_count/(i+1)
                ap += precision_at_k
        ap = ap/min(k,len(relevant_items))
        average_precisions.append(ap)
        
    recall = sum(recall_scores)/len(recall_scores)
    map_ = sum(average_precisions)/len(average_precisions)
    
    print(f"Recall@{k}: {recall:.4f}")
    print(f"MAP@{k}: {map_:.4f}")

# %%
def find_assessments(user_query,k=5):
    model = SentenceTransformer('all-MiniLM-L6-v2')
    query_embedding = model.encode(user_query, convert_to_tensor = True)
    cosine_scores = util.cos_sim(query_embedding,corpus_embeddings)[0]
    top_k = min(k,len(corpus))
    top_results = torch.topk(cosine_scores,k=top_k)
    results = []
    for score, idx in zip(top_results[0], top_results[1]):
        idx = idx.item()
        result = {
            "Assessment Name": catalog_df.iloc[idx]['Assessment Name'],
            "Skills": catalog_df.iloc[idx]['Skills'],
            "Test Type": catalog_df.iloc[idx]['Test Type'],
            "Description": catalog_df.iloc[idx]['Description'],
            "Remote Testing Support": catalog_df.iloc[idx]['Remote Testing Support'],
            "Adaptive/IRT": catalog_df.iloc[idx]['Adaptive/IRT'],
            "Duration": catalog_df.iloc[idx]['Duration'],
            "URL": catalog_df.iloc[idx]['URL'],
            "Score": round(score.item(), 4)
        }
        results.append(result)
    return results

# %%
benchmark_queries = [
    {
        "query": "I am hiring for Java developers who can also collaborate effectively with my business teams. Looking for an assessment that can be completed in 40 minutes.",
        "relevant": ["Java Developer Assessment #1","Quick Java Screening #27","Java Coding Drill #47"]
    },
    {
        "query": "Suggest an assessment for a fresher data analyst that includes Python and SQL skills in under 50 minutes.",
        "relevant": ["Data Analyst Screening #3","SQL & Reporting Challenge #18","Cross-functional Assessment #41"]
    },
    {
        "query": "Looking for remote-enabled JavaScript technical assessment. Needs to be adaptive.",
        "relevant": ["JavaScript Screening Test #11"]
    },
    {
        "query": "Want to assess communication and teamwork skills in under 30 minutes.",
        "relevant": ["Communication Skills Test #19","Business Communication Evaluation #8","Communication & Team Fit #24","Interpersonal Skills Assessment #43"]
    },
]

# %%
compute_metrics(benchmark_queries,k=5)
# Out:
# Recall@5: 0.8542
# MAP@5: 0.7181
